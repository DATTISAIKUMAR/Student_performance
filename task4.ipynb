# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\sai\Downloads\archive (7)\xAPI-Edu-Data.csv")
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
df.StageID.value_counts()
# Out:
# StageID
# MiddleSchool    248
# lowerlevel      199
# HighSchool       33
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
data=df.drop(["gender","NationalITy","Relation","Class","ParentschoolSatisfaction","ParentAnsweringSurvey","PlaceofBirth"],axis=1)
data
# Out:
#           StageID GradeID SectionID      Topic Semester  raisedhands  \
# 0      lowerlevel    G-04         A         IT        F           15
# 1      lowerlevel    G-04         A         IT        F           20
# 2      lowerlevel    G-04         A         IT        F           10
# 3      lowerlevel    G-04         A         IT        F           30
# 4      lowerlevel    G-04         A         IT        F           40
# ..            ...     ...       ...        ...      ...          ...
# 475  MiddleSchool    G-08         A  Chemistry        S            5
# 476  MiddleSchool    G-08         A    Geology        F           50
# 477  MiddleSchool    G-08         A    Geology        S           55
# 478  MiddleSchool    G-08         A    History        F           30
# 479  MiddleSchool    G-08         A    History        S           35
#
#      VisITedResources  AnnouncementsView  Discussion StudentAbsenceDays
# ...

# %%
data.GradeID.value_counts()
# Out:
# GradeID
# G-02    147
# G-08    116
# G-07    101
# G-04     48
# G-06     32
# G-11     13
# G-12     11
# G-09      5
# G-10      4
# G-05      3
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# StageID               0
# GradeID               0
# SectionID             0
# Topic                 0
# Semester              0
# raisedhands           0
# VisITedResources      0
# AnnouncementsView     0
# Discussion            0
# StudentAbsenceDays    0
# dtype: int64

# %%
data.StageID.value_counts()
# Out:
# StageID
# MiddleSchool    248
# lowerlevel      199
# HighSchool       33
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   StageID             480 non-null    object
#  1   GradeID             480 non-null    object
#  2   SectionID           480 non-null    object
#  3   Topic               480 non-null    object
#  4   Semester            480 non-null    object
#  5   raisedhands         480 non-null    int64
#  6   VisITedResources    480 non-null    int64
#  7   AnnouncementsView   480 non-null    int64
#  8   Discussion          480 non-null    int64
#  9   StudentAbsenceDays  480 non-null    object
# dtypes: int64(4), object(6)
# memory usage: 37.6+ KB

# %%
data
# Out:
#           StageID GradeID SectionID      Topic Semester  raisedhands  \
# 0      lowerlevel    G-04         A         IT        F           15
# 1      lowerlevel    G-04         A         IT        F           20
# 2      lowerlevel    G-04         A         IT        F           10
# 3      lowerlevel    G-04         A         IT        F           30
# 4      lowerlevel    G-04         A         IT        F           40
# ..            ...     ...       ...        ...      ...          ...
# 475  MiddleSchool    G-08         A  Chemistry        S            5
# 476  MiddleSchool    G-08         A    Geology        F           50
# 477  MiddleSchool    G-08         A    Geology        S           55
# 478  MiddleSchool    G-08         A    History        F           30
# 479  MiddleSchool    G-08         A    History        S           35
#
#      VisITedResources  AnnouncementsView  Discussion StudentAbsenceDays
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
la=LabelEncoder()

# %%
data["StageID"]=la.fit_transform(data["StageID"])
data["GradeID"]=la.fit_transform(data["GradeID"])
data["Topic"]=la.fit_transform(data["Topic"])
data["Semester"]=la.fit_transform(data["Semester"])
data["SectionID"]=la.fit_transform(data["SectionID"])
data["StudentAbsenceDays"]=la.fit_transform(data["StudentAbsenceDays"])

# %%
import matplotlib.pyplot as plt
for i in data.columns:
    plt.boxplot(data[i])
    plt.show()

# %%
"""def remove_outliers(data,i):
    q25=data[i].quantile(0.25)
    q75=data[i].quantile(0.75)
    iqr=q75-q25
    lower=q25-1.5*iqr
    upper=q75+1.5*iqr
    data=data[data[i]>=lower]
    data=data[data[i]<=upper]
    return data

for i in data.columns:
    data=remove_outliers(data,i)"""
# Out:
# 'def remove_outliers(data,i):\n    q25=data[i].quantile(0.25)\n    q75=data[i].quantile(0.75)\n    iqr=q75-q25\n    lower=q25-1.5*iqr\n    upper=q75+1.5*iqr\n    data=data[data[i]>=lower]\n    data=data[data[i]<=upper]\n    return data\n\nfor i in data.columns:\n    data=remove_outliers(data,i)'

# %%
data
# Out:
#      StageID  GradeID  SectionID  Topic  Semester  raisedhands  \
# 0          2        1          0      7         0           15
# 1          2        1          0      7         0           20
# 2          2        1          0      7         0           10
# 3          2        1          0      7         0           30
# 4          2        1          0      7         0           40
# ..       ...      ...        ...    ...       ...          ...
# 475        1        5          0      2         1            5
# 476        1        5          0      5         0           50
# 477        1        5          0      5         1           55
# 478        1        5          0      6         0           30
# 479        1        5          0      6         1           35
#
#      VisITedResources  AnnouncementsView  Discussion  StudentAbsenceDays
# 0                  16                  2          20                   1
# ...

# %%
x=pd.concat([data.iloc[:,0],data.iloc[:,2:]],axis=1)
y=data.iloc[:,1]

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
mn=MinMaxScaler()
x=mn.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT=DecisionTreeClassifier()

# %%
DT.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_prediction=DT.predict(x_test)
y_prediction
# Out:
# array([0, 5, 0, 5, 4, 0, 0, 5, 0, 0, 0, 5, 5, 0, 5, 1, 0, 0, 5, 4, 4, 5,
#        4, 0, 4, 8, 5, 5, 4, 0, 0, 0, 5, 4, 5, 0, 0, 5, 8, 5, 0, 8, 5, 4,
#        8, 1, 5, 0, 9, 3, 5, 1, 4, 5, 6, 1, 5, 5, 0, 4, 0, 4, 4, 0, 0, 4,
#        4, 4, 0, 0, 7, 4, 0, 1, 0, 5, 5, 4, 0, 4, 4, 3, 4, 5, 1, 4, 5, 5,
#        4, 8, 1, 5, 0, 5, 5, 5])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,ConfusionMatrixDisplay

# %%
print("Accuracy of the data =",accuracy_score(y_prediction,y_test))
print("Confusion Matrix")
cm=confusion_matrix(y_prediction,y_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# Accuracy of the data = 0.96875
# Confusion Matrix

# %%
data.columns
# Out:
# Index(['StageID', 'GradeID', 'SectionID', 'Topic', 'Semester', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'StudentAbsenceDays'],
#       dtype='object')

# %%
df.iloc[0,:]
# Out:
# gender                               M
# NationalITy                         KW
# PlaceofBirth                    KuwaIT
# StageID                     lowerlevel
# GradeID                           G-04
# SectionID                            A
# Topic                               IT
# Semester                             F
# Relation                        Father
# raisedhands                         15
# VisITedResources                    16
# AnnouncementsView                    2
# Discussion                          20
# ParentAnsweringSurvey              Yes
# ParentschoolSatisfaction          Good
# StudentAbsenceDays             Under-7
# Class                                M
# Name: 0, dtype: object

# %%
stageid=list(df["StageID"].unique())
SectionID=list(df["SectionID"].unique())
Topic=list(df["Topic"].unique())
Semester=list(df['Semester'].unique())
StudentAbsenceDays=list(df["StudentAbsenceDays"].unique())

# %%
GradeID=['A','B','C','D','E','F','G','H','I','J']
def preprocessing(model,x_data):
    x_data=mn.fit_transform([x_data])
    y_prediction=model.predict(x_data)
    return GradeID[y_prediction[0]]
print("student preformance prediction",end=" ")
print(preprocessing(DT,[stageid.index('lowerlevel'),SectionID.index('A'),Topic.index('IT'),Semester.index('F'),15,16,2,20,StudentAbsenceDays.index("Under-7")]))
# Out:
# student preformance prediction J

# %%
print("classification report")
print(classification_report(y_prediction,y_test))
# Out:
# classification report
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        28
#            1       1.00      0.86      0.92         7
#            3       0.00      0.00      0.00         2
#            4       0.96      1.00      0.98        22
#            5       0.97      1.00      0.98        29
#            6       1.00      1.00      1.00         1
#            7       1.00      1.00      1.00         1
#            8       1.00      1.00      1.00         5
#            9       1.00      1.00      1.00         1
#
#     accuracy                           0.97        96
#    macro avg       0.88      0.87      0.87        96
# weighted avg       0.95      0.97      0.96        96
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF=RandomForestClassifier()
RF.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_prediction=RF.predict(x_test)
y_prediction
# Out:
# array([0, 5, 0, 5, 4, 0, 0, 5, 0, 0, 0, 5, 5, 0, 5, 1, 0, 0, 5, 4, 4, 5,
#        4, 0, 4, 8, 5, 5, 4, 0, 0, 0, 5, 4, 5, 0, 0, 5, 8, 5, 0, 8, 5, 4,
#        8, 1, 5, 0, 9, 4, 5, 1, 4, 5, 6, 1, 5, 5, 0, 4, 0, 4, 4, 0, 0, 4,
#        4, 5, 0, 0, 5, 4, 0, 1, 0, 5, 5, 5, 0, 4, 4, 4, 4, 5, 1, 4, 5, 5,
#        4, 5, 1, 5, 0, 5, 5, 5])

# %%
accuracy_score(y_prediction,y_test)
# Out:
# 0.9375

# %%
cm=confusion_matrix(y_prediction,y_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
